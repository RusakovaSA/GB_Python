# %% [markdown]
# <a href="https://colab.research.google.com/github/RusakovaSA/GB_Python/blob/main/Task44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  robot
# 2  human
# 3  robot
# 4  robot

# %%
lst
# Out:
# ['robot',
#  'robot',
#  'human',
#  'robot',
#  'robot',
#  'human',
#  'human',
#  'robot',
#  'robot',
#  'human',
#  'human',
#  'human',
#  'human',
#  'robot',
#  'robot',
#  'human',
#  'robot',
#  'human',
#  'human',
#  'robot']

# %%
data.loc[data['whoAmI'] == 'robot', 'robot_group'] = '1'
data.loc[data['whoAmI'] != 'robot', 'robot_group'] = '0'
data.loc[data['whoAmI'] == 'human', 'human_group'] = '1'
data.loc[data['whoAmI'] != 'human', 'human_group'] = '0'
data
# Out:
#    whoAmI robot_group human_group
# 0   robot           1           0
# 1   robot           1           0
# 2   human           0           1
# 3   robot           1           0
# 4   robot           1           0
# 5   human           0           1
# 6   human           0           1
# 7   robot           1           0
# 8   robot           1           0
# 9   human           0           1
# 10  human           0           1
# 11  human           0           1
# 12  human           0           1
# 13  robot           1           0
# 14  robot           1           0
# 15  human           0           1
# 16  robot           1           0
# 17  human           0           1
# 18  human           0           1
# 19  robot           1           0
