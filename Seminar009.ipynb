# %% [markdown]
# <a href="https://colab.research.google.com/github/RusakovaSA/GB_Python/blob/main/Seminar009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
tb = df['total_bedrooms']

# %%
tb
# Out:
# 0        1283.0
# 1        1901.0
# 2         174.0
# 3         337.0
# 4         326.0
#           ...
# 16995     394.0
# 16996     528.0
# 16997     531.0
# 16998     552.0
# 16999     300.0
# Name: total_bedrooms, Length: 17000, dtype: float64

# %%
tb.sum()
# Out:
# 9169984.0

# %%
df[['latitude', 'population']]
# Out:
#        latitude  population
# 0         34.19      1015.0
# 1         34.40      1129.0
# 2         33.69       333.0
# 3         33.64       515.0
# 4         33.57       624.0
# ...         ...         ...
# 16995     40.58       907.0
# 16996     40.69      1194.0
# 16997     41.84      1244.0
# 16998     41.80      1298.0
# 16999     40.54       806.0
#
# [17000 rows x 2 columns]

# %%
new = df[(df['housing_median_age'] < 20) & (df['total_rooms'] <50)]

# %%
new
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 288      -116.76     34.14                 4.0         42.0            10.0
# 1820     -117.27     34.17                16.0         30.0             3.0
# 2907     -117.76     35.22                 4.0         18.0             3.0
# 2990     -117.79     35.21                 4.0          2.0             2.0
# 3049     -117.80     33.63                 8.0         32.0             9.0
# 3275     -117.86     33.67                16.0         20.0             5.0
# 8232     -118.44     34.04                16.0         18.0             6.0
# 9260     -119.09     34.22                 8.0         40.0            10.0
# 13747    -122.00     37.00                16.0         32.0             4.0
#
#        population  households  median_income  median_house_value
# 288           9.0         3.0         0.5360             42500.0
# 1820         49.0         8.0         4.6250            250000.0
# ...

# %%
new.shape
# Out:
# (9, 9)

# %%
new['population'].min()
# Out:
# 3.0

# %%
df[(df['median_income'] < 2)]['median_house_value']
# Out:
# 0        66900.0
# 1        80100.0
# 2        85700.0
# 4        65500.0
# 7        48500.0
#           ...
# 16984    70000.0
# 16989    58100.0
# 16990    78300.0
# 16994    76100.0
# 16998    85800.0
# Name: median_house_value, Length: 2005, dtype: float64

# %%
df[df['median_income']==3.1250][['median_house_value', 'median_income']]
# Out:
#        median_house_value  median_income
# 130               65600.0          3.125
# 606              187500.0          3.125
# 952              216500.0          3.125
# 1134             192200.0          3.125
# 1262             172700.0          3.125
# 1563             117200.0          3.125
# 1909              97600.0          3.125
# 1999             102300.0          3.125
# 2011              92800.0          3.125
# 2896             113600.0          3.125
# 3254             215000.0          3.125
# 3412             168600.0          3.125
# 3838             154100.0          3.125
# 4647             207100.0          3.125
# 4665             120300.0          3.125
# 5360             205600.0          3.125
# 6040             166300.0          3.125
# 7072             380400.0          3.125
# 7577              71300.0          3.125
# 7945             175900.0          3.125
# 8236             343800.0          3.125
# 8358             325000.0          3.125
# ...

# %%
df[(df['median_house_value'] == df['median_house_value'].min())]['population'].max()
# Out:
# 628.0
